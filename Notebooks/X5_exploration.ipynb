# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_pickle('trade_income_transition')

# %%
data['<mean_trajectories>'].unstack('observables')['mean_cluster_size'].unstack(['precip_amplitude', 'r_trade']).plot(legend=False)

# %%
data['<mean_trajectories>'].sort_index(level='observables')
# Out:
# precip_amplitude  r_trade  timesteps  observables
# 0.0               5000.0   0          max_AG                1.0
#                            1          max_AG                2.0
#                            2          max_AG                3.0
#                            3          max_AG                4.0
#                            4          max_AG                5.0
#                            5          max_AG                6.0
#                            6          max_AG                7.0
#                            7          max_AG                8.0
#                            8          max_AG                9.0
#                            9          max_AG               10.0
#                            10         max_AG               11.0
#                            11         max_AG               12.0
#                            12         max_AG               13.0
#                            13         max_AG               14.0
# ...
